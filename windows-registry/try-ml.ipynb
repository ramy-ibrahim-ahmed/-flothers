# %%
import os
import json
import pandas as pd
from glob import glob
import numpy as np

# %%
def load_json_files(directory):
    all_data = []
    json_files = glob(os.path.join(directory, "*.json"))

    for filename in json_files:
        with open(filename, "r") as f:
            data = json.load(f)
            all_data.extend(data)

    df = pd.DataFrame(all_data)
    return df

# %%
directory = r"registry_snapshots"
data = load_json_files(directory)
data = data.drop_duplicates()
data.head()
# Out:
#                                                 path  \
# 0  HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\...
# 1  HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\...
# 2  HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\...
# 3  HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\...
# 4  HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\...
#
#                     value_name  \
# 0               SecurityHealth
# 1               RtkAudUService
# 2          AdobeAAMUpdater-1.0
# 3  Common Administrative Tools
# 4               Common AppData
#
#                                           value_data  value_type
# 0        %windir%\system32\SecurityHealthSystray.exe           2
# 1  "C:\WINDOWS\System32\RtkAudUService64.exe" -ba...           1
# 2  "C:\Program Files (x86)\Common Files\Adobe\OOB...           1
# 3  C:\ProgramData\Microsoft\Windows\Start Menu\Pr...           1
# 4                                     C:\ProgramData           1

# %%
data["value_data_len"] = data["value_data"].apply(len)

# %%
from sklearn.ensemble import IsolationForest

model = IsolationForest(contamination=0.1)
model.fit(data[["value_data_len"]])
# Out:
# IsolationForest(contamination=0.1)

# %%
data["anomaly"] = model.predict(data[["value_data_len"]])
data.head()
# Out:
#                                                 path  \
# 0  HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\...
# 1  HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\...
# 2  HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\...
# 3  HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\...
# 4  HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\...
#
#                     value_name  \
# 0               SecurityHealth
# 1               RtkAudUService
# 2          AdobeAAMUpdater-1.0
# 3  Common Administrative Tools
# 4               Common AppData
#
#                                           value_data  value_type  \
# 0        %windir%\system32\SecurityHealthSystray.exe           2
# 1  "C:\WINDOWS\System32\RtkAudUService64.exe" -ba...           1
# 2  "C:\Program Files (x86)\Common Files\Adobe\OOB...           1
# 3  C:\ProgramData\Microsoft\Windows\Start Menu\Pr...           1
# 4                                     C:\ProgramData           1
#
#    value_data_len  anomaly
# 0              43        1
# 1              54        1
# 2              84       -1
# 3              73        1
# 4              14       -1

# %%
data["anomaly"].value_counts()
# Out:
# anomaly
#  1    88
# -1    10
# Name: count, dtype: int64

# %%
anomalous_rows = data[data["anomaly"] == -1]
anomalous_rows.head()
# Out:
#                                                  path  \
# 2   HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\...
# 4   HKEY_LOCAL_MACHINE\Software\Microsoft\Windows\...
# 15  HKEY_CURRENT_USER\Software\Microsoft\Windows\C...
# 17  HKEY_CURRENT_USER\Software\Microsoft\Windows\C...
# 20  HKEY_CURRENT_USER\Software\Microsoft\Windows\C...
#
#                                            value_name  \
# 2                                 AdobeAAMUpdater-1.0
# 4                                      Common AppData
# 15                                  EpicGamesLauncher
# 17                                      GoogleDriveFS
# 20  MicrosoftEdgeAutoLaunch_B8188322885C6DD24FAC5C...
#
#                                            value_data  value_type  \
# 2   "C:\Program Files (x86)\Common Files\Adobe\OOB...           1
# 4                                      C:\ProgramData           1
# 15  "C:\Program Files (x86)\Epic Games\Launcher\Po...           1
# 17  C:\Program Files\Google\Drive File Stream\94.0...           1
# 20  "C:\Program Files (x86)\Microsoft\Edge\Applica...           1
#
#     value_data_len  anomaly
# 2               84       -1
# 4               14       -1
# 15             116       -1
# 17              83       -1
# 20             102       -1

# %%
text_data = data['value_data'].tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(text_data)

# %%
iso_forest = IsolationForest(contamination='auto', random_state=42)
iso_forest.fit(X)
# Out:
# IsolationForest(random_state=42)

# %%
anomalies = iso_forest.predict(X)
anomalies = np.where(anomalies == -1, True, False)
print("Anomalies detected:", np.sum(anomalies))
# Out:
# Anomalies detected: 1

# %%
data["anomaly"] = anomalies
anomalous_rows = data[data["anomaly"] == True]
anomalous_rows.head()
# Out:
#                                                  path         value_name  \
# 15  HKEY_CURRENT_USER\Software\Microsoft\Windows\C...  EpicGamesLauncher
#
#                                            value_data  value_type  \
# 15  "C:\Program Files (x86)\Epic Games\Launcher\Po...           1
#
#     value_data_len  anomaly
# 15             116     True
